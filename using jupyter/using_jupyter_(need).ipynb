# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # 1 What to expect in this chapter

# %% [markdown]
# # 2 Getting ready

# %% [markdown]
# # 3 Getting started with Jupyter

# %% [markdown]
# ## 3.1 It is all about running cells

# %%
a = 4
b = 65
c = a + b
print(c)
# Out:
# 69

# %% [markdown]
# ## 3.2 A traditional start

# %%
print('Hello World!')

# %% [markdown]
# # 4 All about Markdown

# %% [markdown]
# ## 4.1 Rendering Markdown cells

# %% [markdown]
# The ships hung in the sky in much the same way that bricks don’t.

# %% [markdown]
# ## 4.2 Some basic syntax

# %%
from IPython.display import Image
PATH = "/Users/panjinxia/Documents/NUS/SPS/SP2273/"
Image(filename = PATH  + "L1_markdown_syntax.png", width=200)

# %% [markdown]
# ![](L1_markdown_syntax_copy.png)

# %% [markdown]
# ## 4.3 Headings

# %% [markdown]
# '#' the largest heading<br>
# '##' the second largest heading<br>
# '###' The third-largest heading<br>
# '####' The smallest heading

# %% [markdown]
# ## 4.4 Displaying Code

# %% [markdown]
# Enclose code between two backticks (``) for inline code.<br><br>
# The enclosed code is `print('Hello World!')`

# %% [markdown]
# ## 4.5 Links

# %% [markdown]
# [お前はもう死んでいる](https://www.youtube.com/watch?v=dNQs_Bef_V8)

# %% [markdown]
# ## 4.6 Images

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:640/1*Cw5EWHr4qD3Ktokuk3ZkbQ.jpeg)

# %% [markdown]
# ## 4.7 Tables

# %% [markdown]
# | A    |  B   |    C |
# | :--- | :--: | ---: |
# | a1   |  b1  |   c1 |
# | a2   |  b2  |   c2 |
# | a3   |  b3  |   c3 |

# %% [markdown]
# ## 4.8 Lists

# %% [markdown]
# Numbered-unnumbered lists
# 1. This is point number 1.
# - this is subpoint number 1
# 2. This is point number 2.

# %% [markdown]
# ## 4.9 Equations

# %% [markdown]
# For inline math, use two $ signs.<br>
# For a math block, use two $$ signs.

# %% [markdown]
# The discriminant of a quadratic formula is $\sqrt{b^2-4ac}$

# %% [markdown]
# FINDING THE ROOTS OF A QUADRATIC EQUATION<br>
# $$
# x = \dfrac{-b \pm \sqrt{b^2-4ac}}{2a}
# $$

# %% [markdown]
# ![]()

# %%
from IPython.display import Image
PATH = "/Users/panjinxia/Documents/NUS/SPS/SP2273/"
Image(filename = PATH  + "L1_math_commands.png", width=400)

# %% [markdown]
# For more details, refer to the [mathematical documentation at Overleaf](https://www.overleaf.com/learn/latex/Mathematical_expressions).

# %% [markdown]
# ## Footnotes
